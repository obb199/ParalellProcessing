# %% [markdown]
# # Threads convencionais

# %% [markdown]
# ### compilação

# %%
# !g++ ./threads_version/buffer.hpp ./threads_version/buffer.cpp ./threads_version/maps.hpp ./threads_version/maps.cpp ./threads_version/writer.hpp ./threads_version/writer.cpp ./threads_version/main.cpp -o main_threads

# %% [markdown]
# ### Execução

# %%
# !time ./main_threads
# Out:
# PROCESSED LINES: 175173 in 5 seconds
# ...
# PROCESSED LINES: 344290 in 10 seconds
# ...
# PROCESSED LINES: 542780 in 15 seconds
# ...
# PROCESSED LINES: 726688 in 20 seconds
# ...
# PROCESSED LINES: 914876 in 25 seconds
# ...
# PROCESSED LINES: 1112645 in 30 seconds
# ...
# PROCESSED LINES: 1296119 in 35 seconds
# ...
# PROCESSED LINES: 1473053 in 40 seconds
# ...
# PROCESSED LINES: 1656419 in 45 seconds
# ...
# PROCESSED LINES: 1841927 in 50 seconds
# ...
# PROCESSED LINES: 2031209 in 55 seconds
# ...
# PROCESSED LINES: 2214743 in 60 seconds
# ...
# PROCESSED LINES: 2400744 in 65 seconds
# ...
# PROCESSED LINES: 2581802 in 70 seconds
# ...
# PROCESSED LINES: 2761089 in 75 seconds
# ...
# PROCESSED LINES: 2937041 in 80 seconds
# ...
# PROCESSED LINES: 3110890 in 85 seconds
# ...
# PROCESSED LINES: 3286527 in 90 seconds
# ...
# PROCESSED LINES: 3466785 in 95 seconds
# ...
# PROCESSED LINES: 3652763 in 100 seconds
# ...
# PROCESSED LINES: 3833537 in 105 seconds
# ...
# PROCESSED LINES: 4004406 in 110 seconds
# ...
# PROCESSED LINES: 4192150 in 115 seconds
# ...
# PROCESSED LINES: 4378499 in 120 seconds
# ...

# %% [markdown]
# # Openmp

# %% [markdown]
# ### Compilação

# %%
# !g++ ./openmp_version/buffer.hpp ./openmp_version/buffer.cpp ./openmp_version/maps.hpp ./openmp_version/maps.cpp ./openmp_version/writer.hpp ./openmp_version/writer.cpp ./openmp_version/main.cpp -o main_openmp -fopenmp

# %% [markdown]
# ### Execução

# %%
# !time ./main_openmp
# Out:
# PROCESSED LINES: 1145425 in 5 seconds
# ...
# PROCESSED LINES: 2063603 in 10 seconds
# ...
# PROCESSED LINES: 3049158 in 15 seconds
# ...
# PROCESSED LINES: 4093029 in 20 seconds
# ...
# PROCESSED LINES: 5193798 in 25 seconds
# ...
# PROCESSED LINES: 6277086 in 30 seconds
# ...
# PROCESSED LINES: 7310960 in 35 seconds
# ...
# PROCESSED LINES: 8320823 in 40 seconds
# ...
# PROCESSED LINES: 9359163 in 45 seconds
# ...
# PROCESSED LINES: 10362178 in 50 seconds
# ...
# PROCESSED LINES: 11347468 in 55 seconds
# ...
# PROCESSED LINES: 12334017 in 60 seconds
# ...
# PROCESSED LINES: 13343541 in 65 seconds
# ...
# PROCESSED LINES: 14414260 in 70 seconds
# ...
# PROCESSED LINES: 14665111 in 75 seconds
# ...
#
# real	1m15.022s
# user	2m19.774s
# sys	0m2.971s
